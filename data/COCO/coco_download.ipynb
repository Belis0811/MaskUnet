# %%
import os
import requests
from tqdm import tqdm
import zipfile

# URLs for the required files
urls = {
    "instances_train2017.json": "http://images.cocodataset.org/annotations/annotations_trainval2017.zip",
    "instances_val2017.json": "http://images.cocodataset.org/annotations/annotations_trainval2017.zip",
    "train2017": "http://images.cocodataset.org/zips/train2017.zip",
    "val2017": "http://images.cocodataset.org/zips/val2017.zip",
    "panoptic_train2017.json": "http://images.cocodataset.org/annotations/panoptic_annotations_trainval2017.zip",
    "panoptic_val2017.json": "http://images.cocodataset.org/annotations/panoptic_annotations_trainval2017.zip",
}

# Directory to store the dataset
output_dir = "./"
os.makedirs(output_dir, exist_ok=True)

def download_file(url, output_path):
    """Downloads a file with a progress bar."""
    response = requests.get(url, stream=True)
    total_size = int(response.headers.get('content-length', 0))
    with open(output_path, "wb") as file, tqdm(
        desc=f"Downloading {os.path.basename(output_path)}",
        total=total_size,
        unit="B",
        unit_scale=True,
        unit_divisor=1024,
    ) as bar:
        for data in response.iter_content(chunk_size=1024):
            file.write(data)
            bar.update(len(data))

def extract_file(zip_path, extract_to, specific_files=None):
    """Extracts specific files or all files from a zip archive."""
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        if specific_files:
            for file in specific_files:
                if file in zip_ref.namelist():
                    zip_ref.extract(file, extract_to)
        else:
            zip_ref.extractall(extract_to)

# Step 1: Download and Extract Annotations

#File1: panoptic annotations.json
annotations_zip_path = os.path.join(output_dir, "panoptic_annotations_trainval2017.zip")
if not os.path.exists(annotations_zip_path):
    download_file(urls["panoptic_train2017.json"], annotations_zip_path)

extract_file(
    annotations_zip_path,
    output_dir,
    specific_files=["annotations/panoptic_train2017.json", "annotations/panoptic_val2017.json",]
)
#File2: instance_train2017 json
instance_annotations_zip_path = os.path.join(output_dir, "annotations_trainval2017.zip")
if not os.path.exists(instance_annotations_zip_path):
    download_file(urls["instances_train2017.json"], instance_annotations_zip_path)

extract_file(
    instance_annotations_zip_path, 
    output_dir,
    specific_files=["annotations/instances_train2017.json", "annotations/instances_val2017.json"]
)

# # Step 2: Download and Extract Images (Train)
train_zip_path = os.path.join(output_dir, "train2017.zip")
if not os.path.exists(train_zip_path):
    download_file(urls["train2017"], train_zip_path)

extract_file(train_zip_path, output_dir)

# # Step 3: Download and Extract Images (Validation)
val_zip_path = os.path.join(output_dir, "val2017.zip")
if not os.path.exists(val_zip_path):
    download_file(urls["val2017"], val_zip_path)

extract_file(val_zip_path, output_dir)

# Step4: Download the Extract Images (panoptic_annotations_trainval2017)

path1 = os.path.join(output_dir,"annotations", "panoptic_train2017.zip")
path2 = os.path.join(output_dir, "annotations","panoptic_val2017.zip")

extract_file(path1, output_dir)
extract_file(path2, output_dir)


# Final output paths
annotations_dir = os.path.join(output_dir, "annotations")
train_images_dir = os.path.join(output_dir, "train2017")
val_images_dir = os.path.join(output_dir, "val2017")

print("Dataset downloaded and extracted:")
#print(f"Annotations: {annotations_dir}")
# print(f"Train images: {train_images_dir}")
# print(f"Validation images: {val_images_dir}")
# Out:
# Downloading panoptic_annotations_trainval2017.zip: 100%|██████████| 821M/821M [02:02<00:00, 7.04MB/s]
# Downloading annotations_trainval2017.zip: 100%|██████████| 241M/241M [00:43<00:00, 5.80MB/s]
# Downloading train2017.zip: 100%|██████████| 18.0G/18.0G [34:40<00:00, 9.29MB/s]
# Downloading val2017.zip: 100%|██████████| 778M/778M [01:35<00:00, 8.53MB/s]
# Dataset downloaded and extracted:

# %%
import json
import os
import random
from shutil import copy2
current_directory = os.getcwd()
print(current_directory)


TRAIN_PATH = './'

# Add these debugging lines before your loop
import glob
possible_paths = [
    os.path.join(TRAIN_PATH, 'panoptic_train2017'),
    os.path.join(TRAIN_PATH, 'annotations', 'panoptic_train2017'),
    os.path.join(TRAIN_PATH, 'panoptic_train2017', 'panoptic_train2017')
]

for path in possible_paths:
    if os.path.exists(path):
        print(f"Found path: {path}")
        print(f"Sample files: {glob.glob(os.path.join(path, '*.png'))[:3]}")
# Paths
original_json_path = os.path.join(TRAIN_PATH, 'annotations', 'panoptic_train2017.json')
subset_json_path = os.path.join(TRAIN_PATH, 'annotations', 'panoptic_train_subset.json')
original_img_dir = os.path.join(TRAIN_PATH, 'train2017')
subset_img_dir = os.path.join(TRAIN_PATH, 'train_subset')
subset_panoptic_dir = os.path.join(TRAIN_PATH, 'panoptic_train_subset')

# Parameters
num_samples = 10000

# Create directories for subset
os.makedirs(subset_img_dir, exist_ok=True)
os.makedirs(subset_panoptic_dir, exist_ok=True)

# Load original JSON
with open(original_json_path, 'r') as f:
    panoptic_data = json.load(f)

# Randomly sample images
sampled_images = random.sample(panoptic_data['images'], num_samples)
sampled_image_ids = {img['id'] for img in sampled_images}

# Filter annotations for sampled images
sampled_annotations = [ann for ann in panoptic_data['annotations'] if ann['image_id'] in sampled_image_ids]

# Copy sampled images and annotations
for img in sampled_images:
    src_img_path = os.path.join(original_img_dir, img['file_name'])
    dest_img_path = os.path.join(subset_img_dir, img['file_name'])
    copy2(src_img_path, dest_img_path)

for ann in sampled_annotations:
    src_ann_path = os.path.join(TRAIN_PATH,'panoptic_train2017', ann['file_name'])
    print(src_ann_path)
    dest_ann_path = os.path.join(subset_panoptic_dir, ann['file_name'])
    print(dest_ann_path)
    copy2(src_ann_path, dest_ann_path)

# Save the new JSON
subset_data = {
    'images': sampled_images,
    'annotations': sampled_annotations,
    'categories': panoptic_data['categories'],
}
with open(subset_json_path, 'w') as f:
    json.dump(subset_data, f)

print(f"Subset dataset created with {num_samples} samples.")
# Out:
# s:\Research\MaskUnet\data\COCO
# Found path: ./panoptic_train2017
# Sample files: ['./panoptic_train2017\\000000000009.png', './panoptic_train2017\\000000000025.png', './panoptic_train2017\\000000000030.png']
# ./panoptic_train2017\000000000036.png
# ./panoptic_train_subset\000000000036.png
# ./panoptic_train2017\000000000049.png
# ./panoptic_train_subset\000000000049.png
# ./panoptic_train2017\000000000077.png
# ./panoptic_train_subset\000000000077.png
# ./panoptic_train2017\000000000089.png
# ./panoptic_train_subset\000000000089.png
# ./panoptic_train2017\000000000136.png
# ./panoptic_train_subset\000000000136.png
# ./panoptic_train2017\000000000138.png
# ./panoptic_train_subset\000000000138.png
# ./panoptic_train2017\000000000201.png
# ./panoptic_train_subset\000000000201.png
# ./panoptic_train2017\000000000208.png
# ./panoptic_train_subset\000000000208.png
# ./panoptic_train2017\000000000486.png
# ./panoptic_train_subset\000000000486.png
# ./panoptic_train2017\000000000514.png
# ./panoptic_train_subset\000000000514.png
# ./panoptic_train2017\000000000520.png
# ./panoptic_train_subset\000000000520.png
# ./panoptic_train2017\000000000536.png
# ./panoptic_train_subset\000000000536.png
# ./panoptic_train2017\000000000544.png
# ./panoptic_train_subset\000000000544.png
# ./panoptic_train2017\000000000560.png
# ./panoptic_train_subset\000000000560.png
# ./panoptic_train2017\000000000562.png
# ./panoptic_train_subset\000000000562.png
# ./panoptic_train2017\000000000625.png
# ./panoptic_train_subset\000000000625.png
# ./panoptic_train2017\000000000629.png
# ./panoptic_train_subset\000000000629.png
# ./panoptic_train2017\000000000693.png
# ./panoptic_train_subset\000000000693.png
# ./panoptic_train2017\000000000735.png
# ./panoptic_train_subset\000000000735.png
# ./panoptic_train2017\000000000790.png
# ./panoptic_train_subset\000000000790.png
# ./panoptic_train2017\000000000873.png
# ./panoptic_train_subset\000000000873.png
# ./panoptic_train2017\000000000923.png
# ./panoptic_train_subset\000000000923.png
# ./panoptic_train2017\000000000955.png
# ./panoptic_train_subset\000000000955.png
# ./panoptic_train2017\000000001083.png
# ./panoptic_train_subset\000000001083.png
# ./panoptic_train2017\000000001085.png
# ./panoptic_train_subset\000000001085.png
# ./panoptic_train2017\000000001213.png
# ./panoptic_train_subset\000000001213.png
# ./panoptic_train2017\000000001232.png
# ./panoptic_train_subset\000000001232.png
# ./panoptic_train2017\000000001311.png
# ./panoptic_train_subset\000000001311.png
# ./panoptic_train2017\000000001319.png
# ./panoptic_train_subset\000000001319.png
# ./panoptic_train2017\000000001442.png
# ./panoptic_train_subset\000000001442.png
# ./panoptic_train2017\000000001525.png
# ./panoptic_train_subset\000000001525.png
# ./panoptic_train2017\000000001558.png
# ./panoptic_train_subset\000000001558.png
# ./panoptic_train2017\000000001622.png
# ./panoptic_train_subset\000000001622.png
# ./panoptic_train2017\000000001626.png
# ./panoptic_train_subset\000000001626.png
# ./panoptic_train2017\000000001670.png
# ./panoptic_train_subset\000000001670.png
# ./panoptic_train2017\000000001722.png
# ./panoptic_train_subset\000000001722.png
# ./panoptic_train2017\000000001764.png
# ./panoptic_train_subset\000000001764.png
# ./panoptic_train2017\000000001777.png
# ./panoptic_train_subset\000000001777.png
# ./panoptic_train2017\000000001841.png
# ./panoptic_train_subset\000000001841.png
# ./panoptic_train2017\000000001900.png
# ./panoptic_train_subset\000000001900.png
# ./panoptic_train2017\000000001912.png
# ./panoptic_train_subset\000000001912.png
# ./panoptic_train2017\000000001960.png
# ./panoptic_train_subset\000000001960.png
# ./panoptic_train2017\000000001997.png
# ./panoptic_train_subset\000000001997.png
# ./panoptic_train2017\000000002007.png
# ./panoptic_train_subset\000000002007.png
# ./panoptic_train2017\000000002124.png
# ./panoptic_train_subset\000000002124.png
# ./panoptic_train2017\000000002142.png
# ./panoptic_train_subset\000000002142.png
# ./panoptic_train2017\000000002197.png
# ./panoptic_train_subset\000000002197.png
# ./panoptic_train2017\000000002255.png
# ./panoptic_train_subset\000000002255.png
# ./panoptic_train2017\000000002270.png
# ./panoptic_train_subset\000000002270.png
# ./panoptic_train2017\000000002411.png
# ./panoptic_train_subset\000000002411.png
# ./panoptic_train2017\000000002453.png
# ./panoptic_train_subset\000000002453.png
# ./panoptic_train2017\000000002544.png
# ./panoptic_train_subset\000000002544.png
# ./panoptic_train2017\000000002567.png
# ./panoptic_train_subset\000000002567.png
# ./panoptic_train2017\000000002618.png
# ./panoptic_train_subset\000000002618.png
# ./panoptic_train2017\000000002644.png
# ./panoptic_train_subset\000000002644.png
# ./panoptic_train2017\000000002687.png
# ./panoptic_train_subset\000000002687.png
# ./panoptic_train2017\000000002759.png
# ./panoptic_train_subset\000000002759.png
# ./panoptic_train2017\000000002822.png
# ./panoptic_train_subset\000000002822.png
# ./panoptic_train2017\000000002867.png
# ./panoptic_train_subset\000000002867.png
# ./panoptic_train2017\000000003077.png
# ./panoptic_train_subset\000000003077.png
# ./panoptic_train2017\000000003224.png
# ./panoptic_train_subset\000000003224.png
# ./panoptic_train2017\000000003337.png
# ./panoptic_train_subset\000000003337.png
# ./panoptic_train2017\000000003517.png
# ./panoptic_train_subset\000000003517.png
# ./panoptic_train2017\000000003518.png
# ./panoptic_train_subset\000000003518.png
# ./panoptic_train2017\000000003640.png
# ./panoptic_train_subset\000000003640.png
# ./panoptic_train2017\000000003866.png
# ./panoptic_train_subset\000000003866.png
# ./panoptic_train2017\000000003932.png
# ./panoptic_train_subset\000000003932.png
# ./panoptic_train2017\000000003983.png
# ./panoptic_train_subset\000000003983.png
# ./panoptic_train2017\000000003995.png
# ./panoptic_train_subset\000000003995.png
# ./panoptic_train2017\000000004038.png
# ./panoptic_train_subset\000000004038.png
# ./panoptic_train2017\000000004065.png
# ./panoptic_train_subset\000000004065.png
# ./panoptic_train2017\000000004219.png
# ./panoptic_train_subset\000000004219.png
# ./panoptic_train2017\000000004243.png
# ./panoptic_train_subset\000000004243.png
# ./panoptic_train2017\000000004275.png
# ./panoptic_train_subset\000000004275.png
# ./panoptic_train2017\000000004322.png
# ./panoptic_train_subset\000000004322.png
# ./panoptic_train2017\000000004331.png
# ./panoptic_train_subset\000000004331.png
# ./panoptic_train2017\000000004359.png
# ./panoptic_train_subset\000000004359.png
# ./panoptic_train2017\000000004463.png
# ./panoptic_train_subset\000000004463.png
# ./panoptic_train2017\000000004551.png
# ./panoptic_train_subset\000000004551.png
# ./panoptic_train2017\000000004554.png
# ./panoptic_train_subset\000000004554.png
# ./panoptic_train2017\000000004575.png
# ./panoptic_train_subset\000000004575.png
# ./panoptic_train2017\000000004587.png
# ./panoptic_train_subset\000000004587.png
# ./panoptic_train2017\000000004823.png
# ./panoptic_train_subset\000000004823.png
# ./panoptic_train2017\000000004891.png
# ./panoptic_train_subset\000000004891.png
# ./panoptic_train2017\000000004920.png
# ./panoptic_train_subset\000000004920.png
# ./panoptic_train2017\000000004980.png
# ./panoptic_train_subset\000000004980.png
# ./panoptic_train2017\000000005095.png
# ./panoptic_train_subset\000000005095.png
# ./panoptic_train2017\000000005115.png
# ./panoptic_train_subset\000000005115.png
# ./panoptic_train2017\000000005156.png
# ./panoptic_train_subset\000000005156.png
# ./panoptic_train2017\000000005205.png
# ./panoptic_train_subset\000000005205.png
# ./panoptic_train2017\000000005210.png
# ./panoptic_train_subset\000000005210.png
# ./panoptic_train2017\000000005219.png
# ./panoptic_train_subset\000000005219.png
# ./panoptic_train2017\000000005237.png
# ./panoptic_train_subset\000000005237.png
# ./panoptic_train2017\000000005259.png
# ./panoptic_train_subset\000000005259.png
# ./panoptic_train2017\000000005352.png
# ./panoptic_train_subset\000000005352.png
# ./panoptic_train2017\000000005356.png
# ./panoptic_train_subset\000000005356.png
# ./panoptic_train2017\000000005373.png
# ./panoptic_train_subset\000000005373.png
# ./panoptic_train2017\000000005437.png
# ./panoptic_train_subset\000000005437.png
# ./panoptic_train2017\000000005443.png
# ./panoptic_train_subset\000000005443.png
# ./panoptic_train2017\000000005483.png
# ./panoptic_train_subset\000000005483.png
# ./panoptic_train2017\000000005522.png
# ./panoptic_train_subset\000000005522.png
# ./panoptic_train2017\000000005540.png
# ./panoptic_train_subset\000000005540.png
# ./panoptic_train2017\000000005557.png
# ./panoptic_train_subset\000000005557.png
# ./panoptic_train2017\000000005564.png
# ./panoptic_train_subset\000000005564.png
# ./panoptic_train2017\000000005608.png
# ./panoptic_train_subset\000000005608.png
# ./panoptic_train2017\000000005614.png
# ./panoptic_train_subset\000000005614.png
# ./panoptic_train2017\000000005619.png
# ./panoptic_train_subset\000000005619.png
# ./panoptic_train2017\000000005669.png
# ./panoptic_train_subset\000000005669.png
# ./panoptic_train2017\000000005967.png
# ./panoptic_train_subset\000000005967.png
# ./panoptic_train2017\000000006005.png
# ./panoptic_train_subset\000000006005.png
# ./panoptic_train2017\000000006042.png
# ./panoptic_train_subset\000000006042.png
# ./panoptic_train2017\000000006148.png
# ./panoptic_train_subset\000000006148.png
# ./panoptic_train2017\000000006262.png
# ./panoptic_train_subset\000000006262.png
# ./panoptic_train2017\000000006268.png
# ./panoptic_train_subset\000000006268.png
# ./panoptic_train2017\000000006295.png
# ./panoptic_train_subset\000000006295.png
# ./panoptic_train2017\000000006306.png
# ./panoptic_train_subset\000000006306.png
# ./panoptic_train2017\000000006336.png
# ./panoptic_train_subset\000000006336.png
# ./panoptic_train2017\000000006347.png
# ./panoptic_train_subset\000000006347.png
# ./panoptic_train2017\000000006357.png
# ./panoptic_train_subset\000000006357.png
# ./panoptic_train2017\000000006363.png
# ./panoptic_train_subset\000000006363.png
# ./panoptic_train2017\000000006380.png
# ./panoptic_train_subset\000000006380.png
# ./panoptic_train2017\000000006437.png
# ./panoptic_train_subset\000000006437.png
# ./panoptic_train2017\000000006473.png
# ./panoptic_train_subset\000000006473.png
# ./panoptic_train2017\000000006512.png
# ./panoptic_train_subset\000000006512.png
# ./panoptic_train2017\000000006578.png
# ./panoptic_train_subset\000000006578.png
# ./panoptic_train2017\000000006580.png
# ./panoptic_train_subset\000000006580.png
# ./panoptic_train2017\000000006701.png
# ./panoptic_train_subset\000000006701.png
# ./panoptic_train2017\000000006712.png
# ./panoptic_train_subset\000000006712.png
# ./panoptic_train2017\000000006748.png
# ./panoptic_train_subset\000000006748.png
# ./panoptic_train2017\000000006809.png
# ./panoptic_train_subset\000000006809.png
# ./panoptic_train2017\000000006862.png
# ./panoptic_train_subset\000000006862.png
# ./panoptic_train2017\000000006914.png
# ./panoptic_train_subset\000000006914.png
# ./panoptic_train2017\000000006990.png
# ./panoptic_train_subset\000000006990.png
# ./panoptic_train2017\000000007095.png
# ./panoptic_train_subset\000000007095.png
# ./panoptic_train2017\000000007274.png
# ./panoptic_train_subset\000000007274.png
# ./panoptic_train2017\000000007393.png
# ./panoptic_train_subset\000000007393.png
# ./panoptic_train2017\000000007489.png
# ./panoptic_train_subset\000000007489.png
# ./panoptic_train2017\000000007503.png
# ./panoptic_train_subset\000000007503.png
# ./panoptic_train2017\000000007504.png
# ./panoptic_train_subset\000000007504.png
# ./panoptic_train2017\000000007559.png
# ./panoptic_train_subset\000000007559.png
# ./panoptic_train2017\000000007621.png
# ./panoptic_train_subset\000000007621.png
# ./panoptic_train2017\000000007669.png
# ./panoptic_train_subset\000000007669.png
# ./panoptic_train2017\000000007673.png
# ./panoptic_train_subset\000000007673.png
# ./panoptic_train2017\000000007697.png
# ./panoptic_train_subset\000000007697.png
# ./panoptic_train2017\000000007730.png
# ./panoptic_train_subset\000000007730.png
# ./panoptic_train2017\000000007740.png
# ./panoptic_train_subset\000000007740.png
# ./panoptic_train2017\000000007758.png
# ./panoptic_train_subset\000000007758.png
# ./panoptic_train2017\000000007762.png
# ./panoptic_train_subset\000000007762.png
# ./panoptic_train2017\000000007787.png
# ./panoptic_train_subset\000000007787.png
# ./panoptic_train2017\000000007796.png
# ./panoptic_train_subset\000000007796.png
# ./panoptic_train2017\000000007819.png
# ./panoptic_train_subset\000000007819.png
# ./panoptic_train2017\000000007852.png
# ./panoptic_train_subset\000000007852.png
# ./panoptic_train2017\000000007873.png
# ./panoptic_train_subset\000000007873.png
# ./panoptic_train2017\000000008005.png
# ./panoptic_train_subset\000000008005.png
# ./panoptic_train2017\000000008058.png
# ./panoptic_train_subset\000000008058.png
# ./panoptic_train2017\000000008062.png
# ./panoptic_train_subset\000000008062.png
# ./panoptic_train2017\000000008065.png
# ./panoptic_train_subset\000000008065.png
# ./panoptic_train2017\000000008176.png
# ./panoptic_train_subset\000000008176.png
# ./panoptic_train2017\000000008193.png
# ./panoptic_train_subset\000000008193.png
# ./panoptic_train2017\000000008238.png
# ./panoptic_train_subset\000000008238.png
# ./panoptic_train2017\000000008305.png
# ./panoptic_train_subset\000000008305.png
# ./panoptic_train2017\000000008321.png
# ./panoptic_train_subset\000000008321.png
# ./panoptic_train2017\000000008379.png
# ./panoptic_train_subset\000000008379.png
# ./panoptic_train2017\000000008436.png
# ./panoptic_train_subset\000000008436.png
# ./panoptic_train2017\000000008468.png
# ./panoptic_train_subset\000000008468.png
# ./panoptic_train2017\000000008559.png
# ./panoptic_train_subset\000000008559.png
# ./panoptic_train2017\000000008587.png
# ./panoptic_train_subset\000000008587.png
# ./panoptic_train2017\000000008665.png
# ./panoptic_train_subset\000000008665.png
# ./panoptic_train2017\000000008807.png
# ./panoptic_train_subset\000000008807.png
# ./panoptic_train2017\000000008832.png
# ./panoptic_train_subset\000000008832.png
# ./panoptic_train2017\000000008944.png
# ./panoptic_train_subset\000000008944.png
# ./panoptic_train2017\000000009038.png
# ./panoptic_train_subset\000000009038.png
# ./panoptic_train2017\000000009041.png
# ./panoptic_train_subset\000000009041.png
# ./panoptic_train2017\000000009175.png
# ./panoptic_train_subset\000000009175.png
# ./panoptic_train2017\000000009178.png
# ./panoptic_train_subset\000000009178.png
# ./panoptic_train2017\000000009275.png
# ./panoptic_train_subset\000000009275.png
# ./panoptic_train2017\000000009381.png
# ./panoptic_train_subset\000000009381.png
# ./panoptic_train2017\000000009497.png
# ./panoptic_train_subset\000000009497.png
# ./panoptic_train2017\000000009520.png
# ./panoptic_train_subset\000000009520.png
# ./panoptic_train2017\000000009572.png
# ./panoptic_train_subset\000000009572.png
# ./panoptic_train2017\000000009620.png
# ./panoptic_train_subset\000000009620.png
# ./panoptic_train2017\000000009679.png
# ./panoptic_train_subset\000000009679.png
# ./panoptic_train2017\000000009789.png
# ./panoptic_train_subset\000000009789.png
# ./panoptic_train2017\000000009813.png
# ./panoptic_train_subset\000000009813.png
# ./panoptic_train2017\000000009859.png
# ./panoptic_train_subset\000000009859.png
# ./panoptic_train2017\000000009898.png
# ./panoptic_train_subset\000000009898.png
# ./panoptic_train2017\000000009941.png
# ./panoptic_train_subset\000000009941.png
# ./panoptic_train2017\000000009946.png
# ./panoptic_train_subset\000000009946.png
# ./panoptic_train2017\000000009999.png
# ./panoptic_train_subset\000000009999.png
# ./panoptic_train2017\000000010037.png
# ./panoptic_train_subset\000000010037.png
# ./panoptic_train2017\000000010069.png
# ./panoptic_train_subset\000000010069.png
# ./panoptic_train2017\000000010104.png
# ./panoptic_train_subset\000000010104.png
# ./panoptic_train2017\000000010138.png
# ./panoptic_train_subset\000000010138.png
# ./panoptic_train2017\000000010145.png
# ./panoptic_train_subset\000000010145.png
# ./panoptic_train2017\000000010175.png
# ./panoptic_train_subset\000000010175.png
# ./panoptic_train2017\000000010290.png
# ./panoptic_train_subset\000000010290.png
# ./panoptic_train2017\000000010346.png
# ./panoptic_train_subset\000000010346.png
# ./panoptic_train2017\000000010414.png
# ./panoptic_train_subset\000000010414.png
# ./panoptic_train2017\000000010434.png
# ./panoptic_train_subset\000000010434.png
# ./panoptic_train2017\000000010445.png
# ./panoptic_train_subset\000000010445.png
# ./panoptic_train2017\000000010732.png
# ./panoptic_train_subset\000000010732.png
# ./panoptic_train2017\000000010831.png
# ./panoptic_train_subset\000000010831.png
# ./panoptic_train2017\000000010858.png
# ./panoptic_train_subset\000000010858.png
# ./panoptic_train2017\000000010909.png
# ./panoptic_train_subset\000000010909.png
# ./panoptic_train2017\000000011004.png
# ./panoptic_train_subset\000000011004.png
# ./panoptic_train2017\000000011091.png
# ./panoptic_train_subset\000000011091.png
# ./panoptic_train2017\000000011115.png
# ./panoptic_train_subset\000000011115.png
# ./panoptic_train2017\000000011156.png
# ./panoptic_train_subset\000000011156.png
# ./panoptic_train2017\000000011188.png
# ./panoptic_train_subset\000000011188.png
# ./panoptic_train2017\000000011258.png
# ./panoptic_train_subset\000000011258.png
# ./panoptic_train2017\000000011262.png
# ./panoptic_train_subset\000000011262.png
# ./panoptic_train2017\000000011265.png
# ./panoptic_train_subset\000000011265.png
# ./panoptic_train2017\000000011271.png
# ./panoptic_train_subset\000000011271.png
# ./panoptic_train2017\000000011272.png
# ./panoptic_train_subset\000000011272.png
# ./panoptic_train2017\000000011276.png
# ./panoptic_train_subset\000000011276.png
# ./panoptic_train2017\000000011320.png
# ./panoptic_train_subset\000000011320.png
# ./panoptic_train2017\000000011347.png
# ./panoptic_train_subset\000000011347.png
# ./panoptic_train2017\000000011422.png
# ./panoptic_train_subset\000000011422.png
# ./panoptic_train2017\000000011567.png
# ./panoptic_train_subset\000000011567.png
# ./panoptic_train2017\000000011655.png
# ./panoptic_train_subset\000000011655.png
# ./panoptic_train2017\000000011661.png
# ./panoptic_train_subset\000000011661.png
# ./panoptic_train2017\000000011680.png
# ./panoptic_train_subset\000000011680.png
# ./panoptic_train2017\000000011802.png
# ./panoptic_train_subset\000000011802.png
# ./panoptic_train2017\000000011990.png
# ./panoptic_train_subset\000000011990.png
# ./panoptic_train2017\000000012016.png
# ./panoptic_train_subset\000000012016.png
# ./panoptic_train2017\000000012096.png
# ./panoptic_train_subset\000000012096.png
# ./panoptic_train2017\000000012138.png
# ./panoptic_train_subset\000000012138.png
# ./panoptic_train2017\000000012156.png
# ./panoptic_train_subset\000000012156.png
# ./panoptic_train2017\000000012166.png
# ./panoptic_train_subset\000000012166.png
# ./panoptic_train2017\000000012181.png
# ./panoptic_train_subset\000000012181.png
# ./panoptic_train2017\000000012204.png
# ./panoptic_train_subset\000000012204.png
# ./panoptic_train2017\000000012224.png
# ./panoptic_train_subset\000000012224.png
# ./panoptic_train2017\000000012233.png
# ./panoptic_train_subset\000000012233.png
# ./panoptic_train2017\000000012251.png
# ./panoptic_train_subset\000000012251.png
# ./panoptic_train2017\000000012372.png
# ./panoptic_train_subset\000000012372.png
# ./panoptic_train2017\000000012756.png
# ./panoptic_train_subset\000000012756.png
# ./panoptic_train2017\000000012810.png
# ./panoptic_train_subset\000000012810.png
# ./panoptic_train2017\000000012864.png
# ./panoptic_train_subset\000000012864.png
# ./panoptic_train2017\000000012897.png
# ./panoptic_train_subset\000000012897.png
# ./panoptic_train2017\000000012923.png
# ./panoptic_train_subset\000000012923.png
# ./panoptic_train2017\000000012930.png
# ./panoptic_train_subset\000000012930.png
# ./panoptic_train2017\000000012943.png
# ./panoptic_train_subset\000000012943.png
# ./panoptic_train2017\000000013045.png
# ./panoptic_train_subset\000000013045.png
# ./panoptic_train2017\000000013124.png
# ./panoptic_train_subset\000000013124.png
# ./panoptic_train2017\000000013188.png
# ./panoptic_train_subset\000000013188.png
# ./panoptic_train2017\000000013220.png
# ./panoptic_train_subset\000000013220.png
# ./panoptic_train2017\000000013279.png
# ./panoptic_train_subset\000000013279.png
# ./panoptic_train2017\000000013283.png
# ./panoptic_train_subset\000000013283.png
# ./panoptic_train2017\000000013333.png
# ./panoptic_train_subset\000000013333.png
# ./panoptic_train2017\000000013455.png
# ./panoptic_train_subset\000000013455.png
# ./panoptic_train2017\000000013473.png
# ./panoptic_train_subset\000000013473.png
# ./panoptic_train2017\000000013637.png
# ./panoptic_train_subset\000000013637.png
# ./panoptic_train2017\000000013678.png
# ./panoptic_train_subset\000000013678.png
# ./panoptic_train2017\000000013770.png
# ./panoptic_train_subset\000000013770.png
# ./panoptic_train2017\000000013802.png
# ./panoptic_train_subset\000000013802.png
# ./panoptic_train2017\000000013856.png
# ./panoptic_train_subset\000000013856.png
# ./panoptic_train2017\000000013882.png
# ./panoptic_train_subset\000000013882.png
# ./panoptic_train2017\000000014004.png
# ./panoptic_train_subset\000000014004.png
# ./panoptic_train2017\000000014073.png
# ./panoptic_train_subset\000000014073.png
# ./panoptic_train2017\000000014135.png
# ./panoptic_train_subset\000000014135.png
# ./panoptic_train2017\000000014271.png
# ./panoptic_train_subset\000000014271.png
# ./panoptic_train2017\000000014338.png
# ./panoptic_train_subset\000000014338.png
# ./panoptic_train2017\000000014377.png
# ./panoptic_train_subset\000000014377.png
# ./panoptic_train2017\000000014487.png
# ./panoptic_train_subset\000000014487.png
# ./panoptic_train2017\000000014514.png
# ./panoptic_train_subset\000000014514.png
# ./panoptic_train2017\000000014546.png
# ./panoptic_train_subset\000000014546.png
# ./panoptic_train2017\000000014798.png
# ./panoptic_train_subset\000000014798.png
# ./panoptic_train2017\000000014820.png
# ./panoptic_train_subset\000000014820.png
# ./panoptic_train2017\000000014835.png
# ./panoptic_train_subset\000000014835.png
# ./panoptic_train2017\000000014850.png
# ./panoptic_train_subset\000000014850.png
# ./panoptic_train2017\000000014990.png
# ./panoptic_train_subset\000000014990.png
# ./panoptic_train2017\000000015096.png
# ./panoptic_train_subset\000000015096.png
# ./panoptic_train2017\000000015157.png
# ./panoptic_train_subset\000000015157.png
# ./panoptic_train2017\000000015197.png
# ./panoptic_train_subset\000000015197.png
# ./panoptic_train2017\000000015198.png
# ./panoptic_train_subset\000000015198.png
# ./panoptic_train2017\000000015236.png
# ./panoptic_train_subset\000000015236.png
# ./panoptic_train2017\000000015267.png
# ./panoptic_train_subset\000000015267.png
# ./panoptic_train2017\000000015311.png
# ./panoptic_train_subset\000000015311.png
# ./panoptic_train2017\000000015404.png
# ./panoptic_train_subset\000000015404.png
# ./panoptic_train2017\000000015409.png
# ./panoptic_train_subset\000000015409.png
# ./panoptic_train2017\000000015472.png
# ./panoptic_train_subset\000000015472.png
# ./panoptic_train2017\000000015524.png
# ./panoptic_train_subset\000000015524.png
# ./panoptic_train2017\000000015542.png
# ./panoptic_train_subset\000000015542.png
# ./panoptic_train2017\000000015544.png
# ./panoptic_train_subset\000000015544.png
# ./panoptic_train2017\000000015558.png
# ./panoptic_train_subset\000000015558.png
# ./panoptic_train2017\000000015566.png
# ./panoptic_train_subset\000000015566.png
# ./panoptic_train2017\000000015586.png
# ./panoptic_train_subset\000000015586.png
# ./panoptic_train2017\000000015600.png
# ./panoptic_train_subset\000000015600.png
# ./panoptic_train2017\000000015621.png
# ./panoptic_train_subset\000000015621.png
# ./panoptic_train2017\000000015757.png
# ./panoptic_train_subset\000000015757.png
# ./panoptic_train2017\000000015772.png
# ./panoptic_train_subset\000000015772.png
# ./panoptic_train2017\000000015823.png
# ./panoptic_train_subset\000000015823.png
# ./panoptic_train2017\000000015843.png
# ./panoptic_train_subset\000000015843.png
# ./panoptic_train2017\000000015870.png
# ./panoptic_train_subset\000000015870.png
# ./panoptic_train2017\000000016064.png
# ./panoptic_train_subset\000000016064.png
# ./panoptic_train2017\000000016076.png
# ./panoptic_train_subset\000000016076.png
# ./panoptic_train2017\000000016098.png
# ./panoptic_train_subset\000000016098.png
# ./panoptic_train2017\000000016161.png
# ./panoptic_train_subset\000000016161.png
# ./panoptic_train2017\000000016173.png
# ./panoptic_train_subset\000000016173.png
# ./panoptic_train2017\000000016257.png
# ./panoptic_train_subset\000000016257.png
# ./panoptic_train2017\000000016318.png
# ./panoptic_train_subset\000000016318.png
# ./panoptic_train2017\000000016342.png
# ./panoptic_train_subset\000000016342.png
# ./panoptic_train2017\000000016362.png
# ./panoptic_train_subset\000000016362.png
# ./panoptic_train2017\000000016383.png
# ./panoptic_train_subset\000000016383.png
# ./panoptic_train2017\000000016448.png
# ./panoptic_train_subset\000000016448.png
# ./panoptic_train2017\000000016575.png
# ./panoptic_train_subset\000000016575.png
# ./panoptic_train2017\000000016653.png
# ./panoptic_train_subset\000000016653.png
# ./panoptic_train2017\000000016706.png
# ./panoptic_train_subset\000000016706.png
# ./panoptic_train2017\000000016730.png
# ./panoptic_train_subset\000000016730.png
# ./panoptic_train2017\000000016759.png
# ./panoptic_train_subset\000000016759.png
# ./panoptic_train2017\000000016879.png
# ./panoptic_train_subset\000000016879.png
# ./panoptic_train2017\000000017047.png
# ./panoptic_train_subset\000000017047.png
# ./panoptic_train2017\000000017147.png
# ./panoptic_train_subset\000000017147.png
# ./panoptic_train2017\000000017166.png
# ./panoptic_train_subset\000000017166.png
# ./panoptic_train2017\000000017236.png
# ./panoptic_train_subset\000000017236.png
# ./panoptic_train2017\000000017450.png
# ./panoptic_train_subset\000000017450.png
# ./panoptic_train2017\000000017460.png
# ./panoptic_train_subset\000000017460.png
# ./panoptic_train2017\000000017472.png
# ./panoptic_train_subset\000000017472.png
# ./panoptic_train2017\000000017573.png
# ./panoptic_train_subset\000000017573.png
# ./panoptic_train2017\000000017625.png
# ./panoptic_train_subset\000000017625.png
# ./panoptic_train2017\000000017667.png
# ./panoptic_train_subset\000000017667.png
# ./panoptic_train2017\000000017715.png
# ./panoptic_train_subset\000000017715.png
# ./panoptic_train2017\000000017717.png
# ./panoptic_train_subset\000000017717.png
# ./panoptic_train2017\000000017751.png
# ./panoptic_train_subset\000000017751.png
# ./panoptic_train2017\000000017791.png
# ./panoptic_train_subset\000000017791.png
# ./panoptic_train2017\000000017799.png
# ./panoptic_train_subset\000000017799.png
# ./panoptic_train2017\000000018093.png
# ./panoptic_train_subset\000000018093.png
# ./panoptic_train2017\000000018099.png
# ./panoptic_train_subset\000000018099.png
# ./panoptic_train2017\000000018179.png
# ./panoptic_train_subset\000000018179.png
# ./panoptic_train2017\000000018233.png
# ./panoptic_train_subset\000000018233.png
# ./panoptic_train2017\000000018276.png
# ./panoptic_train_subset\000000018276.png
# ./panoptic_train2017\000000018317.png
# ./panoptic_train_subset\000000018317.png
# ./panoptic_train2017\000000018375.png
# ./panoptic_train_subset\000000018375.png
# ./panoptic_train2017\000000018414.png
# ./panoptic_train_subset\000000018414.png
# ./panoptic_train2017\000000018461.png
# ./panoptic_train_subset\000000018461.png
# ./panoptic_train2017\000000018462.png
# ./panoptic_train_subset\000000018462.png
# ./panoptic_train2017\000000018542.png
# ./panoptic_train_subset\000000018542.png
# ./panoptic_train2017\000000018555.png
# ./panoptic_train_subset\000000018555.png
# ./panoptic_train2017\000000018584.png
# ./panoptic_train_subset\000000018584.png
# ./panoptic_train2017\000000018633.png
# ./panoptic_train_subset\000000018633.png
# ./panoptic_train2017\000000018666.png
# ./panoptic_train_subset\000000018666.png
# ./panoptic_train2017\000000018683.png
# ./panoptic_train_subset\000000018683.png
# ./panoptic_train2017\000000018728.png
# ./panoptic_train_subset\000000018728.png
# ./panoptic_train2017\000000018748.png
# ./panoptic_train_subset\000000018748.png
# ./panoptic_train2017\000000018811.png
# ./panoptic_train_subset\000000018811.png
# ./panoptic_train2017\000000018882.png
# ./panoptic_train_subset\000000018882.png
# ./panoptic_train2017\000000018903.png
# ./panoptic_train_subset\000000018903.png
# ./panoptic_train2017\000000018918.png
# ./panoptic_train_subset\000000018918.png
# ./panoptic_train2017\000000018994.png
# ./panoptic_train_subset\000000018994.png
# ./panoptic_train2017\000000019037.png
# ./panoptic_train_subset\000000019037.png
# ./panoptic_train2017\000000019185.png
# ./panoptic_train_subset\000000019185.png
# ./panoptic_train2017\000000019194.png
# ./panoptic_train_subset\000000019194.png
# ./panoptic_train2017\000000019198.png
# ./panoptic_train_subset\000000019198.png
# ./panoptic_train2017\000000019240.png
# ./panoptic_train_subset\000000019240.png
# ./panoptic_train2017\000000019251.png
# ./panoptic_train_subset\000000019251.png
# ./panoptic_train2017\000000019275.png
# ./panoptic_train_subset\000000019275.png
# ./panoptic_train2017\000000019333.png
# ./panoptic_train_subset\000000019333.png
# ./panoptic_train2017\000000019413.png
# ./panoptic_train_subset\000000019413.png
# ./panoptic_train2017\000000019489.png
# ./panoptic_train_subset\000000019489.png
# ./panoptic_train2017\000000019542.png
# ./panoptic_train_subset\000000019542.png
# ./panoptic_train2017\000000019714.png
# ./panoptic_train_subset\000000019714.png
# ./panoptic_train2017\000000019737.png
# ./panoptic_train_subset\000000019737.png
# ./panoptic_train2017\000000019783.png
# ./panoptic_train_subset\000000019783.png
# ./panoptic_train2017\000000019874.png
# ./panoptic_train_subset\000000019874.png
# ./panoptic_train2017\000000019918.png
# ./panoptic_train_subset\000000019918.png
# ./panoptic_train2017\000000019955.png
# ./panoptic_train_subset\000000019955.png
# ./panoptic_train2017\000000019974.png
# ./panoptic_train_subset\000000019974.png
# ./panoptic_train2017\000000020031.png
# ./panoptic_train_subset\000000020031.png
# ./panoptic_train2017\000000020106.png
# ./panoptic_train_subset\000000020106.png
# ./panoptic_train2017\000000020136.png
# ./panoptic_train_subset\000000020136.png
# ./panoptic_train2017\000000020147.png
# ./panoptic_train_subset\000000020147.png
# ./panoptic_train2017\000000020202.png
# ./panoptic_train_subset\000000020202.png
# ./panoptic_train2017\000000020434.png
# ./panoptic_train_subset\000000020434.png
# ./panoptic_train2017\000000020549.png
# ./panoptic_train_subset\000000020549.png
# ./panoptic_train2017\000000020583.png
# ./panoptic_train_subset\000000020583.png
# ./panoptic_train2017\000000020608.png
# ./panoptic_train_subset\000000020608.png
# ./panoptic_train2017\000000020711.png
# ./panoptic_train_subset\000000020711.png
# ./panoptic_train2017\000000020818.png
# ./panoptic_train_subset\000000020818.png
# ./panoptic_train2017\000000020857.png
# ./panoptic_train_subset\000000020857.png
# ./panoptic_train2017\000000021051.png
# ./panoptic_train_subset\000000021051.png
# ./panoptic_train2017\000000021079.png
# ./panoptic_train_subset\000000021079.png
# ./panoptic_train2017\000000021095.png
# ./panoptic_train_subset\000000021095.png
# ./panoptic_train2017\000000021152.png
# ./panoptic_train_subset\000000021152.png
# ./panoptic_train2017\000000021166.png
# ./panoptic_train_subset\000000021166.png
# ./panoptic_train2017\000000021254.png
# ./panoptic_train_subset\000000021254.png
# ./panoptic_train2017\000000021260.png
# ./panoptic_train_subset\000000021260.png
# ./panoptic_train2017\000000021387.png
# ./panoptic_train_subset\000000021387.png
# ./panoptic_train2017\000000021417.png
# ./panoptic_train_subset\000000021417.png
# ./panoptic_train2017\000000021469.png
# ./panoptic_train_subset\000000021469.png
# ./panoptic_train2017\000000021483.png
# ./panoptic_train_subset\000000021483.png
# ./panoptic_train2017\000000021563.png
# ./panoptic_train_subset\000000021563.png
# ./panoptic_train2017\000000021566.png
# ./panoptic_train_subset\000000021566.png
# ./panoptic_train2017\000000021641.png
# ./panoptic_train_subset\000000021641.png
# ./panoptic_train2017\000000021645.png
# ./panoptic_train_subset\000000021645.png
# ./panoptic_train2017\000000021780.png
# ./panoptic_train_subset\000000021780.png
# ./panoptic_train2017\000000021883.png
# ./panoptic_train_subset\000000021883.png
# ./panoptic_train2017\000000021915.png
# ./panoptic_train_subset\000000021915.png
# ./panoptic_train2017\000000022135.png
# ./panoptic_train_subset\000000022135.png
# ./panoptic_train2017\000000022176.png
# ./panoptic_train_subset\000000022176.png
# ./panoptic_train2017\000000022274.png
# ./panoptic_train_subset\000000022274.png
# ./panoptic_train2017\000000022326.png
# ./panoptic_train_subset\000000022326.png
# ./panoptic_train2017\000000022536.png
# ./panoptic_train_subset\000000022536.png
# ./panoptic_train2017\000000022671.png
# ./panoptic_train_subset\000000022671.png
# ./panoptic_train2017\000000022815.png
# ./panoptic_train_subset\000000022815.png
# ./panoptic_train2017\000000022838.png
# ./panoptic_train_subset\000000022838.png
# ./panoptic_train2017\000000022857.png
# ./panoptic_train_subset\000000022857.png
# ./panoptic_train2017\000000022983.png
# ./panoptic_train_subset\000000022983.png
# ./panoptic_train2017\000000023100.png
# ./panoptic_train_subset\000000023100.png
# ./panoptic_train2017\000000023117.png
# ./panoptic_train_subset\000000023117.png
# ./panoptic_train2017\000000023121.png
# ./panoptic_train_subset\000000023121.png
# ./panoptic_train2017\000000023251.png
# ./panoptic_train_subset\000000023251.png
# ./panoptic_train2017\000000023363.png
# ./panoptic_train_subset\000000023363.png
# ./panoptic_train2017\000000023400.png
# ./panoptic_train_subset\000000023400.png
# ./panoptic_train2017\000000023406.png
# ./panoptic_train_subset\000000023406.png
# ./panoptic_train2017\000000023450.png
# ./panoptic_train_subset\000000023450.png
# ./panoptic_train2017\000000023542.png
# ./panoptic_train_subset\000000023542.png
# ./panoptic_train2017\000000023575.png
# ./panoptic_train_subset\000000023575.png
# ./panoptic_train2017\000000023591.png
# ./panoptic_train_subset\000000023591.png
# ./panoptic_train2017\000000023807.png
# ./panoptic_train_subset\000000023807.png
# ./panoptic_train2017\000000023893.png
# ./panoptic_train_subset\000000023893.png
# ./panoptic_train2017\000000023908.png
# ./panoptic_train_subset\000000023908.png
# ./panoptic_train2017\000000024036.png
# ./panoptic_train_subset\000000024036.png
# ./panoptic_train2017\000000024095.png
# ./panoptic_train_subset\000000024095.png
# ./panoptic_train2017\000000024129.png
# ./panoptic_train_subset\000000024129.png
# ./panoptic_train2017\000000024253.png
# ./panoptic_train_subset\000000024253.png
# ./panoptic_train2017\000000024260.png
# ./panoptic_train_subset\000000024260.png
# ./panoptic_train2017\000000024266.png
# ./panoptic_train_subset\000000024266.png
# ./panoptic_train2017\000000024393.png
# ./panoptic_train_subset\000000024393.png
# ./panoptic_train2017\000000024396.png
# ./panoptic_train_subset\000000024396.png
# ./panoptic_train2017\000000024446.png
# ./panoptic_train_subset\000000024446.png
# ./panoptic_train2017\000000024450.png
# ./panoptic_train_subset\000000024450.png
# ./panoptic_train2017\000000024763.png
# ./panoptic_train_subset\000000024763.png
# ./panoptic_train2017\000000024779.png
# ./panoptic_train_subset\000000024779.png
# ./panoptic_train2017\000000024813.png
# ./panoptic_train_subset\000000024813.png
# ./panoptic_train2017\000000024861.png
# ./panoptic_train_subset\000000024861.png
# ./panoptic_train2017\000000024915.png
# ./panoptic_train_subset\000000024915.png
# ./panoptic_train2017\000000024948.png
# ./panoptic_train_subset\000000024948.png
# ./panoptic_train2017\000000025009.png
# ./panoptic_train_subset\000000025009.png
# ./panoptic_train2017\000000025014.png
# ./panoptic_train_subset\000000025014.png
# ./panoptic_train2017\000000025115.png
# ./panoptic_train_subset\000000025115.png
# ./panoptic_train2017\000000025230.png
# ./panoptic_train_subset\000000025230.png
# ./panoptic_train2017\000000025273.png
# ./panoptic_train_subset\000000025273.png
# ./panoptic_train2017\000000025293.png
# ./panoptic_train_subset\000000025293.png
# ./panoptic_train2017\000000025411.png
# ./panoptic_train_subset\000000025411.png
# ./panoptic_train2017\000000025506.png
# ./panoptic_train_subset\000000025506.png
# ./panoptic_train2017\000000025515.png
# ./panoptic_train_subset\000000025515.png
# ./panoptic_train2017\000000025533.png
# ./panoptic_train_subset\000000025533.png
# ./panoptic_train2017\000000025539.png
# ./panoptic_train_subset\000000025539.png
# ./panoptic_train2017\000000025541.png
# ./panoptic_train_subset\000000025541.png
# ./panoptic_train2017\000000025549.png
# ./panoptic_train_subset\000000025549.png
# ./panoptic_train2017\000000025717.png
# ./panoptic_train_subset\000000025717.png
# ./panoptic_train2017\000000025816.png
# ./panoptic_train_subset\000000025816.png
# ./panoptic_train2017\000000025853.png
# ./panoptic_train_subset\000000025853.png
# ./panoptic_train2017\000000025855.png
# ./panoptic_train_subset\000000025855.png
# ./panoptic_train2017\000000025907.png
# ./panoptic_train_subset\000000025907.png
# ./panoptic_train2017\000000025917.png
# ./panoptic_train_subset\000000025917.png
# ./panoptic_train2017\000000026024.png
# ./panoptic_train_subset\000000026024.png
# ./panoptic_train2017\000000026053.png
# ./panoptic_train_subset\000000026053.png
# ./panoptic_train2017\000000026190.png
# ./panoptic_train_subset\000000026190.png
# ./panoptic_train2017\000000026233.png
# ./panoptic_train_subset\000000026233.png
# ./panoptic_train2017\000000026247.png
# ./panoptic_train_subset\000000026247.png
# ./panoptic_train2017\000000026260.png
# ./panoptic_train_subset\000000026260.png
# ./panoptic_train2017\000000026266.png
# ./panoptic_train_subset\000000026266.png
# ./panoptic_train2017\000000026281.png
# ./panoptic_train_subset\000000026281.png
# ./panoptic_train2017\000000026359.png
# ./panoptic_train_subset\000000026359.png
# ./panoptic_train2017\000000026368.png
# ./panoptic_train_subset\000000026368.png
# ./panoptic_train2017\000000026393.png
# ./panoptic_train_subset\000000026393.png
# ./panoptic_train2017\000000026448.png
# ./panoptic_train_subset\000000026448.png
# ./panoptic_train2017\000000026583.png
# ./panoptic_train_subset\000000026583.png
# ./panoptic_train2017\000000026584.png
# ./panoptic_train_subset\000000026584.png
# ./panoptic_train2017\000000026611.png
# ./panoptic_train_subset\000000026611.png
# ./panoptic_train2017\000000026647.png
# ./panoptic_train_subset\000000026647.png
# ./panoptic_train2017\000000026652.png
# ./panoptic_train_subset\000000026652.png
# ./panoptic_train2017\000000026733.png
# ./panoptic_train_subset\000000026733.png
# ./panoptic_train2017\000000026784.png
# ./panoptic_train_subset\000000026784.png
# ./panoptic_train2017\000000026818.png
# ./panoptic_train_subset\000000026818.png
# ./panoptic_train2017\000000026884.png
# ./panoptic_train_subset\000000026884.png
# ./panoptic_train2017\000000026988.png
# ./panoptic_train_subset\000000026988.png
# ./panoptic_train2017\000000026997.png
# ./panoptic_train_subset\000000026997.png
# ./panoptic_train2017\000000027009.png
# ./panoptic_train_subset\000000027009.png
# ./panoptic_train2017\000000027030.png
# ./panoptic_train_subset\000000027030.png
# ./panoptic_train2017\000000027063.png
# ./panoptic_train_subset\000000027063.png
# ./panoptic_train2017\000000027226.png
# ./panoptic_train_subset\000000027226.png
# ./panoptic_train2017\000000027241.png
# ./panoptic_train_subset\000000027241.png
# ./panoptic_train2017\000000027285.png
# ./panoptic_train_subset\000000027285.png
# ./panoptic_train2017\000000027417.png
# ./panoptic_train_subset\000000027417.png
# ./panoptic_train2017\000000027524.png
# ./panoptic_train_subset\000000027524.png
# ./panoptic_train2017\000000027565.png
# ./panoptic_train_subset\000000027565.png
# ./panoptic_train2017\000000027569.png
# ./panoptic_train_subset\000000027569.png
# ./panoptic_train2017\000000027829.png
# ./panoptic_train_subset\000000027829.png
# ./panoptic_train2017\000000027888.png
# ./panoptic_train_subset\000000027888.png
# ./panoptic_train2017\000000027890.png
# ./panoptic_train_subset\000000027890.png
# ./panoptic_train2017\000000027920.png
# ./panoptic_train_subset\000000027920.png
# ./panoptic_train2017\000000027929.png
# ./panoptic_train_subset\000000027929.png
# ./panoptic_train2017\000000027942.png
# ./panoptic_train_subset\000000027942.png
# ./panoptic_train2017\000000027977.png
# ./panoptic_train_subset\000000027977.png
# ./panoptic_train2017\000000028110.png
# ./panoptic_train_subset\000000028110.png
# ./panoptic_train2017\000000028114.png
# ./panoptic_train_subset\000000028114.png
# ./panoptic_train2017\000000028134.png
# ./panoptic_train_subset\000000028134.png
# ./panoptic_train2017\000000028184.png
# ./panoptic_train_subset\000000028184.png
# ./panoptic_train2017\000000028209.png
# ./panoptic_train_subset\000000028209.png
# ./panoptic_train2017\000000028261.png
# ./panoptic_train_subset\000000028261.png
# ./panoptic_train2017\000000028263.png
# ./panoptic_train_subset\000000028263.png
# ./panoptic_train2017\000000028276.png
# ./panoptic_train_subset\000000028276.png
# ./panoptic_train2017\000000028304.png
# ./panoptic_train_subset\000000028304.png
# ./panoptic_train2017\000000028320.png
# ./panoptic_train_subset\000000028320.png
# ./panoptic_train2017\000000028451.png
# ./panoptic_train_subset\000000028451.png
# ./panoptic_train2017\000000028462.png
# ./panoptic_train_subset\000000028462.png
# ./panoptic_train2017\000000028499.png
# ./panoptic_train_subset\000000028499.png
# ./panoptic_train2017\000000028517.png
# ./panoptic_train_subset\000000028517.png
# ./panoptic_train2017\000000028540.png
# ./panoptic_train_subset\000000028540.png
# ./panoptic_train2017\000000028607.png
# ./panoptic_train_subset\000000028607.png
# ./panoptic_train2017\000000028658.png
# ./panoptic_train_subset\000000028658.png
# ./panoptic_train2017\000000028675.png
# ./panoptic_train_subset\000000028675.png
# ./panoptic_train2017\000000028692.png
# ./panoptic_train_subset\000000028692.png
# ./panoptic_train2017\000000028728.png
# ./panoptic_train_subset\000000028728.png
# ./panoptic_train2017\000000028887.png
# ./panoptic_train_subset\000000028887.png
# ./panoptic_train2017\000000028924.png
# ./panoptic_train_subset\000000028924.png
# ./panoptic_train2017\000000028955.png
# ./panoptic_train_subset\000000028955.png
# ./panoptic_train2017\000000028976.png
# ./panoptic_train_subset\000000028976.png
# ./panoptic_train2017\000000029122.png
# ./panoptic_train_subset\000000029122.png
# ./panoptic_train2017\000000029145.png
# ./panoptic_train_subset\000000029145.png
# ./panoptic_train2017\000000029146.png
# ./panoptic_train_subset\000000029146.png
# ./panoptic_train2017\000000029151.png
# ./panoptic_train_subset\000000029151.png
# ./panoptic_train2017\000000029182.png
# ./panoptic_train_subset\000000029182.png
# ./panoptic_train2017\000000029224.png
# ./panoptic_train_subset\000000029224.png
# ./panoptic_train2017\000000029322.png
# ./panoptic_train_subset\000000029322.png
# ./panoptic_train2017\000000029345.png
# ./panoptic_train_subset\000000029345.png
# ./panoptic_train2017\000000029432.png
# ./panoptic_train_subset\000000029432.png
# ./panoptic_train2017\000000029465.png
# ./panoptic_train_subset\000000029465.png
# ./panoptic_train2017\000000029559.png
# ./panoptic_train_subset\000000029559.png
# ./panoptic_train2017\000000029577.png
# ./panoptic_train_subset\000000029577.png
# ./panoptic_train2017\000000029802.png
# ./panoptic_train_subset\000000029802.png
# ./panoptic_train2017\000000029894.png
# ./panoptic_train_subset\000000029894.png
# ./panoptic_train2017\000000029909.png
# ./panoptic_train_subset\000000029909.png
# ./panoptic_train2017\000000029931.png
# ./panoptic_train_subset\000000029931.png
# ./panoptic_train2017\000000029934.png
# ./panoptic_train_subset\000000029934.png
# ./panoptic_train2017\000000030065.png
# ./panoptic_train_subset\000000030065.png
# ./panoptic_train2017\000000030143.png
# ./panoptic_train_subset\000000030143.png
# ./panoptic_train2017\000000030210.png
# ./panoptic_train_subset\000000030210.png
# ./panoptic_train2017\000000030239.png
# ./panoptic_train_subset\000000030239.png
# ./panoptic_train2017\000000030267.png
# ./panoptic_train_subset\000000030267.png
# ./panoptic_train2017\000000030270.png
# ./panoptic_train_subset\000000030270.png
# ./panoptic_train2017\000000030299.png
# ./panoptic_train_subset\000000030299.png
# ./panoptic_train2017\000000030340.png
# ./panoptic_train_subset\000000030340.png
# ./panoptic_train2017\000000030356.png
# ./panoptic_train_subset\000000030356.png
# ./panoptic_train2017\000000030361.png
# ./panoptic_train_subset\000000030361.png
# ./panoptic_train2017\000000030389.png
# ./panoptic_train_subset\000000030389.png
# ./panoptic_train2017\000000030423.png
# ./panoptic_train_subset\000000030423.png
# ./panoptic_train2017\000000030508.png
# ./panoptic_train_subset\000000030508.png
# ./panoptic_train2017\000000030519.png
# ./panoptic_train_subset\000000030519.png
# ./panoptic_train2017\000000030526.png
# ./panoptic_train_subset\000000030526.png
# ./panoptic_train2017\000000030645.png
# ./panoptic_train_subset\000000030645.png
# ./panoptic_train2017\000000030674.png
# ./panoptic_train_subset\000000030674.png
# ./panoptic_train2017\000000030713.png
# ./panoptic_train_subset\000000030713.png
# ./panoptic_train2017\000000030775.png
# ./panoptic_train_subset\000000030775.png
# ./panoptic_train2017\000000030838.png
# ./panoptic_train_subset\000000030838.png
# ./panoptic_train2017\000000030856.png
# ./panoptic_train_subset\000000030856.png
# ./panoptic_train2017\000000030954.png
# ./panoptic_train_subset\000000030954.png
# ./panoptic_train2017\000000031016.png
# ./panoptic_train_subset\000000031016.png
# ./panoptic_train2017\000000031061.png
# ./panoptic_train_subset\000000031061.png
# ./panoptic_train2017\000000031073.png
# ./panoptic_train_subset\000000031073.png
# ./panoptic_train2017\000000031081.png
# ./panoptic_train_subset\000000031081.png
# ./panoptic_train2017\000000031092.png
# ./panoptic_train_subset\000000031092.png
# ./panoptic_train2017\000000031157.png
# ./panoptic_train_subset\000000031157.png
# ./panoptic_train2017\000000031161.png
# ./panoptic_train_subset\000000031161.png
# ./panoptic_train2017\000000031164.png
# ./panoptic_train_subset\000000031164.png
# ./panoptic_train2017\000000031281.png
# ./panoptic_train_subset\000000031281.png
# ./panoptic_train2017\000000031333.png
# ./panoptic_train_subset\000000031333.png
# ./panoptic_train2017\000000031339.png
# ./panoptic_train_subset\000000031339.png
# ./panoptic_train2017\000000031411.png
# ./panoptic_train_subset\000000031411.png
# ./panoptic_train2017\000000031562.png
# ./panoptic_train_subset\000000031562.png
# ./panoptic_train2017\000000031597.png
# ./panoptic_train_subset\000000031597.png
# ./panoptic_train2017\000000031699.png
# ./panoptic_train_subset\000000031699.png
# ./panoptic_train2017\000000031738.png
# ./panoptic_train_subset\000000031738.png
# ./panoptic_train2017\000000031913.png
# ./panoptic_train_subset\000000031913.png
# ./panoptic_train2017\000000032044.png
# ./panoptic_train_subset\000000032044.png
# ./panoptic_train2017\000000032126.png
# ./panoptic_train_subset\000000032126.png
# ./panoptic_train2017\000000032220.png
# ./panoptic_train_subset\000000032220.png
# ./panoptic_train2017\000000032468.png
# ./panoptic_train_subset\000000032468.png
# ./panoptic_train2017\000000032606.png
# ./panoptic_train_subset\000000032606.png
# ./panoptic_train2017\000000032689.png
# ./panoptic_train_subset\000000032689.png
# ./panoptic_train2017\000000032699.png
# ./panoptic_train_subset\000000032699.png
# ./panoptic_train2017\000000032850.png
# ./panoptic_train_subset\000000032850.png
# ./panoptic_train2017\000000032877.png
# ./panoptic_train_subset\000000032877.png
# ./panoptic_train2017\000000032892.png
# ./panoptic_train_subset\000000032892.png
# ./panoptic_train2017\000000032964.png
# ./panoptic_train_subset\000000032964.png
# ./panoptic_train2017\000000032984.png
# ./panoptic_train_subset\000000032984.png
# ./panoptic_train2017\000000033009.png
# ./panoptic_train_subset\000000033009.png
# ./panoptic_train2017\000000033127.png
# ./panoptic_train_subset\000000033127.png
# ./panoptic_train2017\000000033186.png
# ./panoptic_train_subset\000000033186.png
# ./panoptic_train2017\000000033352.png
# ./panoptic_train_subset\000000033352.png
# ./panoptic_train2017\000000033500.png
# ./panoptic_train_subset\000000033500.png
# ./panoptic_train2017\000000033505.png
# ./panoptic_train_subset\000000033505.png
# ./panoptic_train2017\000000033576.png
# ./panoptic_train_subset\000000033576.png
# ./panoptic_train2017\000000033761.png
# ./panoptic_train_subset\000000033761.png
# ./panoptic_train2017\000000033808.png
# ./panoptic_train_subset\000000033808.png
# ./panoptic_train2017\000000033883.png
# ./panoptic_train_subset\000000033883.png
# ./panoptic_train2017\000000033939.png
# ./panoptic_train_subset\000000033939.png
# ./panoptic_train2017\000000033940.png
# ./panoptic_train_subset\000000033940.png
# ./panoptic_train2017\000000033955.png
# ./panoptic_train_subset\000000033955.png
# ./panoptic_train2017\000000033959.png
# ./panoptic_train_subset\000000033959.png
# ./panoptic_train2017\000000033974.png
# ./panoptic_train_subset\000000033974.png
# ./panoptic_train2017\000000033991.png
# ./panoptic_train_subset\000000033991.png
# ./panoptic_train2017\000000033998.png
# ./panoptic_train_subset\000000033998.png
# ...
# ./panoptic_train_subset\000000570516.png
# ./panoptic_train2017\000000570545.png
# ./panoptic_train_subset\000000570545.png
# ./panoptic_train2017\000000570569.png
# ./panoptic_train_subset\000000570569.png
# ./panoptic_train2017\000000570601.png
# ./panoptic_train_subset\000000570601.png
# ./panoptic_train2017\000000570608.png
# ./panoptic_train_subset\000000570608.png
# ./panoptic_train2017\000000570629.png
# ./panoptic_train_subset\000000570629.png
# ./panoptic_train2017\000000570721.png
# ./panoptic_train_subset\000000570721.png
# ./panoptic_train2017\000000570775.png
# ./panoptic_train_subset\000000570775.png
# ./panoptic_train2017\000000570951.png
# ./panoptic_train_subset\000000570951.png
# ./panoptic_train2017\000000570981.png
# ./panoptic_train_subset\000000570981.png
# ./panoptic_train2017\000000571047.png
# ./panoptic_train_subset\000000571047.png
# ./panoptic_train2017\000000571174.png
# ./panoptic_train_subset\000000571174.png
# ./panoptic_train2017\000000571236.png
# ./panoptic_train_subset\000000571236.png
# ./panoptic_train2017\000000571407.png
# ./panoptic_train_subset\000000571407.png
# ./panoptic_train2017\000000571443.png
# ./panoptic_train_subset\000000571443.png
# ./panoptic_train2017\000000571499.png
# ./panoptic_train_subset\000000571499.png
# ./panoptic_train2017\000000571548.png
# ./panoptic_train_subset\000000571548.png
# ./panoptic_train2017\000000571562.png
# ./panoptic_train_subset\000000571562.png
# ./panoptic_train2017\000000571640.png
# ./panoptic_train_subset\000000571640.png
# ./panoptic_train2017\000000571678.png
# ./panoptic_train_subset\000000571678.png
# ./panoptic_train2017\000000571790.png
# ./panoptic_train_subset\000000571790.png
# ./panoptic_train2017\000000571792.png
# ./panoptic_train_subset\000000571792.png
# ./panoptic_train2017\000000571847.png
# ./panoptic_train_subset\000000571847.png
# ./panoptic_train2017\000000571938.png
# ./panoptic_train_subset\000000571938.png
# ./panoptic_train2017\000000571944.png
# ./panoptic_train_subset\000000571944.png
# ./panoptic_train2017\000000571946.png
# ./panoptic_train_subset\000000571946.png
# ./panoptic_train2017\000000571996.png
# ./panoptic_train_subset\000000571996.png
# ./panoptic_train2017\000000572000.png
# ./panoptic_train_subset\000000572000.png
# ./panoptic_train2017\000000572063.png
# ./panoptic_train_subset\000000572063.png
# ./panoptic_train2017\000000572095.png
# ./panoptic_train_subset\000000572095.png
# ./panoptic_train2017\000000572250.png
# ./panoptic_train_subset\000000572250.png
# ./panoptic_train2017\000000572284.png
# ./panoptic_train_subset\000000572284.png
# ./panoptic_train2017\000000572316.png
# ./panoptic_train_subset\000000572316.png
# ./panoptic_train2017\000000572347.png
# ./panoptic_train_subset\000000572347.png
# ./panoptic_train2017\000000572349.png
# ./panoptic_train_subset\000000572349.png
# ./panoptic_train2017\000000572477.png
# ./panoptic_train_subset\000000572477.png
# ./panoptic_train2017\000000572508.png
# ./panoptic_train_subset\000000572508.png
# ./panoptic_train2017\000000572592.png
# ./panoptic_train_subset\000000572592.png
# ./panoptic_train2017\000000572611.png
# ./panoptic_train_subset\000000572611.png
# ./panoptic_train2017\000000572615.png
# ./panoptic_train_subset\000000572615.png
# ./panoptic_train2017\000000572725.png
# ./panoptic_train_subset\000000572725.png
# ./panoptic_train2017\000000572751.png
# ./panoptic_train_subset\000000572751.png
# ./panoptic_train2017\000000572752.png
# ./panoptic_train_subset\000000572752.png
# ./panoptic_train2017\000000572767.png
# ./panoptic_train_subset\000000572767.png
# ./panoptic_train2017\000000572861.png
# ./panoptic_train_subset\000000572861.png
# ./panoptic_train2017\000000572899.png
# ./panoptic_train_subset\000000572899.png
# ./panoptic_train2017\000000572991.png
# ./panoptic_train_subset\000000572991.png
# ./panoptic_train2017\000000573134.png
# ./panoptic_train_subset\000000573134.png
# ./panoptic_train2017\000000573179.png
# ./panoptic_train_subset\000000573179.png
# ./panoptic_train2017\000000573191.png
# ./panoptic_train_subset\000000573191.png
# ./panoptic_train2017\000000573196.png
# ./panoptic_train_subset\000000573196.png
# ./panoptic_train2017\000000573225.png
# ./panoptic_train_subset\000000573225.png
# ./panoptic_train2017\000000573254.png
# ./panoptic_train_subset\000000573254.png
# ./panoptic_train2017\000000573260.png
# ./panoptic_train_subset\000000573260.png
# ./panoptic_train2017\000000573314.png
# ./panoptic_train_subset\000000573314.png
# ./panoptic_train2017\000000573355.png
# ./panoptic_train_subset\000000573355.png
# ./panoptic_train2017\000000573401.png
# ./panoptic_train_subset\000000573401.png
# ./panoptic_train2017\000000573431.png
# ./panoptic_train_subset\000000573431.png
# ./panoptic_train2017\000000573456.png
# ./panoptic_train_subset\000000573456.png
# ./panoptic_train2017\000000573509.png
# ./panoptic_train_subset\000000573509.png
# ./panoptic_train2017\000000573605.png
# ./panoptic_train_subset\000000573605.png
# ./panoptic_train2017\000000573647.png
# ./panoptic_train_subset\000000573647.png
# ./panoptic_train2017\000000573653.png
# ./panoptic_train_subset\000000573653.png
# ./panoptic_train2017\000000573750.png
# ./panoptic_train_subset\000000573750.png
# ./panoptic_train2017\000000573756.png
# ./panoptic_train_subset\000000573756.png
# ./panoptic_train2017\000000573882.png
# ./panoptic_train_subset\000000573882.png
# ./panoptic_train2017\000000573885.png
# ./panoptic_train_subset\000000573885.png
# ./panoptic_train2017\000000573894.png
# ./panoptic_train_subset\000000573894.png
# ./panoptic_train2017\000000573920.png
# ./panoptic_train_subset\000000573920.png
# ./panoptic_train2017\000000573958.png
# ./panoptic_train_subset\000000573958.png
# ./panoptic_train2017\000000573975.png
# ./panoptic_train_subset\000000573975.png
# ./panoptic_train2017\000000574025.png
# ./panoptic_train_subset\000000574025.png
# ./panoptic_train2017\000000574032.png
# ./panoptic_train_subset\000000574032.png
# ./panoptic_train2017\000000574059.png
# ./panoptic_train_subset\000000574059.png
# ./panoptic_train2017\000000574095.png
# ./panoptic_train_subset\000000574095.png
# ./panoptic_train2017\000000574110.png
# ./panoptic_train_subset\000000574110.png
# ./panoptic_train2017\000000574138.png
# ./panoptic_train_subset\000000574138.png
# ./panoptic_train2017\000000574244.png
# ./panoptic_train_subset\000000574244.png
# ./panoptic_train2017\000000574250.png
# ./panoptic_train_subset\000000574250.png
# ./panoptic_train2017\000000574460.png
# ./panoptic_train_subset\000000574460.png
# ./panoptic_train2017\000000574506.png
# ./panoptic_train_subset\000000574506.png
# ./panoptic_train2017\000000574538.png
# ./panoptic_train_subset\000000574538.png
# ./panoptic_train2017\000000574602.png
# ./panoptic_train_subset\000000574602.png
# ./panoptic_train2017\000000574633.png
# ./panoptic_train_subset\000000574633.png
# ./panoptic_train2017\000000574747.png
# ./panoptic_train_subset\000000574747.png
# ./panoptic_train2017\000000574769.png
# ./panoptic_train_subset\000000574769.png
# ./panoptic_train2017\000000574790.png
# ./panoptic_train_subset\000000574790.png
# ./panoptic_train2017\000000574795.png
# ./panoptic_train_subset\000000574795.png
# ./panoptic_train2017\000000574818.png
# ./panoptic_train_subset\000000574818.png
# ./panoptic_train2017\000000574884.png
# ./panoptic_train_subset\000000574884.png
# ./panoptic_train2017\000000574992.png
# ./panoptic_train_subset\000000574992.png
# ./panoptic_train2017\000000575055.png
# ./panoptic_train_subset\000000575055.png
# ./panoptic_train2017\000000575079.png
# ./panoptic_train_subset\000000575079.png
# ./panoptic_train2017\000000575173.png
# ./panoptic_train_subset\000000575173.png
# ./panoptic_train2017\000000575199.png
# ./panoptic_train_subset\000000575199.png
# ./panoptic_train2017\000000575305.png
# ./panoptic_train_subset\000000575305.png
# ./panoptic_train2017\000000575354.png
# ./panoptic_train_subset\000000575354.png
# ./panoptic_train2017\000000575437.png
# ./panoptic_train_subset\000000575437.png
# ./panoptic_train2017\000000575441.png
# ./panoptic_train_subset\000000575441.png
# ./panoptic_train2017\000000575497.png
# ./panoptic_train_subset\000000575497.png
# ./panoptic_train2017\000000575511.png
# ./panoptic_train_subset\000000575511.png
# ./panoptic_train2017\000000575590.png
# ./panoptic_train_subset\000000575590.png
# ./panoptic_train2017\000000575743.png
# ./panoptic_train_subset\000000575743.png
# ./panoptic_train2017\000000575792.png
# ./panoptic_train_subset\000000575792.png
# ./panoptic_train2017\000000575839.png
# ./panoptic_train_subset\000000575839.png
# ./panoptic_train2017\000000575857.png
# ./panoptic_train_subset\000000575857.png
# ./panoptic_train2017\000000575873.png
# ./panoptic_train_subset\000000575873.png
# ./panoptic_train2017\000000575902.png
# ./panoptic_train_subset\000000575902.png
# ./panoptic_train2017\000000575916.png
# ./panoptic_train_subset\000000575916.png
# ./panoptic_train2017\000000575980.png
# ./panoptic_train_subset\000000575980.png
# ./panoptic_train2017\000000576015.png
# ./panoptic_train_subset\000000576015.png
# ./panoptic_train2017\000000576088.png
# ./panoptic_train_subset\000000576088.png
# ./panoptic_train2017\000000576128.png
# ./panoptic_train_subset\000000576128.png
# ./panoptic_train2017\000000576295.png
# ./panoptic_train_subset\000000576295.png
# ./panoptic_train2017\000000576322.png
# ./panoptic_train_subset\000000576322.png
# ./panoptic_train2017\000000576363.png
# ./panoptic_train_subset\000000576363.png
# ./panoptic_train2017\000000576427.png
# ./panoptic_train_subset\000000576427.png
# ./panoptic_train2017\000000576431.png
# ./panoptic_train_subset\000000576431.png
# ./panoptic_train2017\000000576468.png
# ./panoptic_train_subset\000000576468.png
# ./panoptic_train2017\000000576530.png
# ./panoptic_train_subset\000000576530.png
# ./panoptic_train2017\000000576638.png
# ./panoptic_train_subset\000000576638.png
# ./panoptic_train2017\000000576701.png
# ./panoptic_train_subset\000000576701.png
# ./panoptic_train2017\000000576756.png
# ./panoptic_train_subset\000000576756.png
# ./panoptic_train2017\000000576816.png
# ./panoptic_train_subset\000000576816.png
# ./panoptic_train2017\000000576831.png
# ./panoptic_train_subset\000000576831.png
# ./panoptic_train2017\000000577036.png
# ./panoptic_train_subset\000000577036.png
# ./panoptic_train2017\000000577051.png
# ./panoptic_train_subset\000000577051.png
# ./panoptic_train2017\000000577207.png
# ./panoptic_train_subset\000000577207.png
# ./panoptic_train2017\000000577213.png
# ./panoptic_train_subset\000000577213.png
# ./panoptic_train2017\000000577343.png
# ./panoptic_train_subset\000000577343.png
# ./panoptic_train2017\000000577351.png
# ./panoptic_train_subset\000000577351.png
# ./panoptic_train2017\000000577448.png
# ./panoptic_train_subset\000000577448.png
# ./panoptic_train2017\000000577637.png
# ./panoptic_train_subset\000000577637.png
# ./panoptic_train2017\000000577657.png
# ./panoptic_train_subset\000000577657.png
# ./panoptic_train2017\000000577723.png
# ./panoptic_train_subset\000000577723.png
# ./panoptic_train2017\000000577748.png
# ./panoptic_train_subset\000000577748.png
# ./panoptic_train2017\000000577819.png
# ./panoptic_train_subset\000000577819.png
# ./panoptic_train2017\000000577835.png
# ./panoptic_train_subset\000000577835.png
# ./panoptic_train2017\000000577838.png
# ./panoptic_train_subset\000000577838.png
# ./panoptic_train2017\000000577877.png
# ./panoptic_train_subset\000000577877.png
# ./panoptic_train2017\000000578002.png
# ./panoptic_train_subset\000000578002.png
# ./panoptic_train2017\000000578131.png
# ./panoptic_train_subset\000000578131.png
# ./panoptic_train2017\000000578147.png
# ./panoptic_train_subset\000000578147.png
# ./panoptic_train2017\000000578164.png
# ./panoptic_train_subset\000000578164.png
# ./panoptic_train2017\000000578213.png
# ./panoptic_train_subset\000000578213.png
# ./panoptic_train2017\000000578232.png
# ./panoptic_train_subset\000000578232.png
# ./panoptic_train2017\000000578314.png
# ./panoptic_train_subset\000000578314.png
# ./panoptic_train2017\000000578376.png
# ./panoptic_train_subset\000000578376.png
# ./panoptic_train2017\000000578385.png
# ./panoptic_train_subset\000000578385.png
# ./panoptic_train2017\000000578466.png
# ./panoptic_train_subset\000000578466.png
# ./panoptic_train2017\000000578481.png
# ./panoptic_train_subset\000000578481.png
# ./panoptic_train2017\000000578521.png
# ./panoptic_train_subset\000000578521.png
# ./panoptic_train2017\000000578596.png
# ./panoptic_train_subset\000000578596.png
# ./panoptic_train2017\000000578597.png
# ./panoptic_train_subset\000000578597.png
# ./panoptic_train2017\000000578619.png
# ./panoptic_train_subset\000000578619.png
# ./panoptic_train2017\000000578649.png
# ./panoptic_train_subset\000000578649.png
# ./panoptic_train2017\000000578740.png
# ./panoptic_train_subset\000000578740.png
# ./panoptic_train2017\000000578769.png
# ./panoptic_train_subset\000000578769.png
# ./panoptic_train2017\000000578808.png
# ./panoptic_train_subset\000000578808.png
# ./panoptic_train2017\000000578846.png
# ./panoptic_train_subset\000000578846.png
# ./panoptic_train2017\000000578984.png
# ./panoptic_train_subset\000000578984.png
# ./panoptic_train2017\000000579405.png
# ./panoptic_train_subset\000000579405.png
# ./panoptic_train2017\000000579415.png
# ./panoptic_train_subset\000000579415.png
# ./panoptic_train2017\000000579466.png
# ./panoptic_train_subset\000000579466.png
# ./panoptic_train2017\000000579568.png
# ./panoptic_train_subset\000000579568.png
# ./panoptic_train2017\000000579571.png
# ./panoptic_train_subset\000000579571.png
# ./panoptic_train2017\000000579666.png
# ./panoptic_train_subset\000000579666.png
# ./panoptic_train2017\000000579667.png
# ./panoptic_train_subset\000000579667.png
# ./panoptic_train2017\000000579673.png
# ./panoptic_train_subset\000000579673.png
# ./panoptic_train2017\000000579729.png
# ./panoptic_train_subset\000000579729.png
# ./panoptic_train2017\000000579787.png
# ./panoptic_train_subset\000000579787.png
# ./panoptic_train2017\000000579952.png
# ./panoptic_train_subset\000000579952.png
# ./panoptic_train2017\000000579964.png
# ./panoptic_train_subset\000000579964.png
# ./panoptic_train2017\000000580002.png
# ./panoptic_train_subset\000000580002.png
# ./panoptic_train2017\000000580082.png
# ./panoptic_train_subset\000000580082.png
# ./panoptic_train2017\000000580108.png
# ./panoptic_train_subset\000000580108.png
# ./panoptic_train2017\000000580381.png
# ./panoptic_train_subset\000000580381.png
# ./panoptic_train2017\000000580431.png
# ./panoptic_train_subset\000000580431.png
# ./panoptic_train2017\000000580505.png
# ./panoptic_train_subset\000000580505.png
# ./panoptic_train2017\000000580512.png
# ./panoptic_train_subset\000000580512.png
# ./panoptic_train2017\000000580562.png
# ./panoptic_train_subset\000000580562.png
# ./panoptic_train2017\000000580586.png
# ./panoptic_train_subset\000000580586.png
# ./panoptic_train2017\000000580678.png
# ./panoptic_train_subset\000000580678.png
# ./panoptic_train2017\000000580835.png
# ./panoptic_train_subset\000000580835.png
# ./panoptic_train2017\000000580842.png
# ./panoptic_train_subset\000000580842.png
# ./panoptic_train2017\000000580851.png
# ./panoptic_train_subset\000000580851.png
# ./panoptic_train2017\000000580908.png
# ./panoptic_train_subset\000000580908.png
# ./panoptic_train2017\000000580951.png
# ./panoptic_train_subset\000000580951.png
# ./panoptic_train2017\000000581031.png
# ./panoptic_train_subset\000000581031.png
# ./panoptic_train2017\000000581071.png
# ./panoptic_train_subset\000000581071.png
# ./panoptic_train2017\000000581097.png
# ./panoptic_train_subset\000000581097.png
# ./panoptic_train2017\000000581180.png
# ./panoptic_train_subset\000000581180.png
# ./panoptic_train2017\000000581226.png
# ./panoptic_train_subset\000000581226.png
# ./panoptic_train2017\000000581310.png
# ./panoptic_train_subset\000000581310.png
# ./panoptic_train2017\000000581507.png
# ./panoptic_train_subset\000000581507.png
# ./panoptic_train2017\000000581542.png
# ./panoptic_train_subset\000000581542.png
# ./panoptic_train2017\000000581571.png
# ./panoptic_train_subset\000000581571.png
# ./panoptic_train2017\000000581670.png
# ./panoptic_train_subset\000000581670.png
# ./panoptic_train2017\000000581715.png
# ./panoptic_train_subset\000000581715.png
# ./panoptic_train2017\000000581886.png
# ./panoptic_train_subset\000000581886.png
# ./panoptic_train2017\000000581900.png
# ./panoptic_train_subset\000000581900.png
# ./panoptic_train2017\000000581904.png
# ./panoptic_train_subset\000000581904.png
# Subset dataset created with 10000 samples.
